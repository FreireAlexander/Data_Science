# %% [markdown]
# # Importamos las librerias

# %%
import numpy as np 
import pandas as pd

# %%
df_accidentes_resumen = pd.read_excel('../datos/raw/relacion_accidentes_resumen_eventos.xls')
df_accidentes_resumen
# Out:
#          Croquis Fecha radica Fecha accidente  Año accidente Mes accidente  \
# 0     A001228652   13/01/2021      01/01/2021           2021    Enero
# 1     A001228696   12/01/2021      01/01/2021           2021    Enero
# 2     A001228683   07/01/2021      01/01/2021           2021    Enero
# 3     A001228656   13/01/2021      02/01/2021           2021    Enero
# 4     A001228710   22/01/2021      02/01/2021           2021    Enero
# ...          ...          ...             ...            ...           ...
# 8777  A001484241   29/03/2023      26/03/2023           2023    Marzo
# 8778  A001484244   30/03/2023      26/03/2023           2023    Marzo
# 8779  A001484245   29/03/2023      26/03/2023           2023    Marzo
# 8780  A001484243   30/03/2023      26/03/2023           2023    Marzo
# 8781  A001484250   29/03/2023      27/03/2023           2023    Marzo
#
#      Dia accidente hora accidente Fecha levanta Hora levanta     Gravedad  \
# ...
